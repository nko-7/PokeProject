# %%
from pokemontcgsdk import Card
from pokemontcgsdk import Set
from pokemontcgsdk import Type
from pokemontcgsdk import Supertype
from pokemontcgsdk import Subtype
from pokemontcgsdk import Rarity

# %%
import pandas as pd

# %%
from pokemontcgsdk import RestClient

RestClient.configure('YOUR KEY HERE')

# %%
card = Card.all()

# %%
print(type(card))
# Out:
# <class 'list'>

# %%
PokeFrame = pd.DataFrame(card)

# %%
PokeFrame
# Out:
#                                                abilities            artist  \
# 0      [{'name': 'Jamming', 'text': 'After your oppon...      Kouki Saitou
# 1      [{'name': 'Reactive Protection', 'text': 'Any ...   Hajime Kusajima
# 2                                                   None             Sekio
# 3      [{'name': 'Froth', 'text': 'Once during your t...  Sumiyoshi Kizuki
# 4                                                   None   Mitsuhiro Arita
# ...                                                  ...               ...
# 18501                                               None              None
# 18502                                               None              None
# 18503                                               None              None
# 18504                                               None              None
# 18505                                               None              None
#
#       ancientTrait                                            attacks  \
# 0             None  [{'name': 'Cluster Bolt', 'cost': ['Lightning'...
# 1             None  [{'name': 'Power Blow', 'cost': ['Colorless'],...
# 2             None  [{'name': 'Surprise Attack', 'cost': ['Grass']...
# 3             None  [{'name': 'Water Punch', 'cost': ['Water', 'Co...
# 4             None  [{'name': 'Pollen Hazard', 'cost': ['Grass', '...
# ...            ...                                                ...
# 18501         None  [{'name': 'Brave Wing', 'cost': ['Fire'], 'con...
# 18502         None  [{'name': 'Horrifying Fang', 'cost': ['Psychic...
# 18503         None  [{'name': 'Power Splash', 'cost': ['Water'], '...
# 18504         None  [{'name': 'Flare Strike', 'cost': ['Fire', 'Co...
# 18505         None  [{'name': 'Unified Beatdown', 'cost': ['Colorl...
#
#                                               cardmarket  \
# 0      {'url': 'https://prices.pokemontcg.io/cardmark...
# 1      {'url': 'https://prices.pokemontcg.io/cardmark...
# 2      {'url': 'https://prices.pokemontcg.io/cardmark...
# 3      {'url': 'https://prices.pokemontcg.io/cardmark...
# 4      {'url': 'https://prices.pokemontcg.io/cardmark...
# ...                                                  ...
# 18501  {'url': 'https://prices.pokemontcg.io/cardmark...
# 18502  {'url': 'https://prices.pokemontcg.io/cardmark...
# 18503  {'url': 'https://prices.pokemontcg.io/cardmark...
# 18504  {'url': 'https://prices.pokemontcg.io/cardmark...
# 18505  {'url': 'https://prices.pokemontcg.io/cardmark...
#
#        convertedRetreatCost        evolvesFrom  \
# 0                       3.0            Flaaffy
# 1                       NaN  Mysterious Fossil
# 2                       1.0               None
# 3                       1.0             Marill
# 4                       4.0               None
# ...                     ...                ...
# 18501                   2.0         Charmeleon
# 18502                   3.0           Greavard
# 18503                   2.0               None
# 18504                   NaN             Raboot
# 18505                   2.0               None
#
#                                               flavorText   hp       id  ...  \
# 0      The tip of its tail shines brightly. In the ol...  130    dp3-1  ...
# 1                                                   None   70   ex12-1  ...
# 2      When attacked by bird Pokémon, it resists by r...   50  mcd19-1  ...
# 3                                                   None   80    ex7-1  ...
# 4                                                   None  270    sm9-1  ...
# ...                                                  ...  ...      ...  ...
# 18501                                               None  330  svp-161  ...
# 18502                                               None  260  svp-162  ...
# 18503                                               None  220  svp-164  ...
# 18504                                               None  320  svp-163  ...
# 18505                                               None  230  svp-165  ...
#
#              rarity                             resistances  \
# 0         Rare Holo     [{'type': 'Metal', 'value': '-20'}]
# 1         Rare Holo  [{'type': 'Fighting', 'value': '-30'}]
# 2              None                                    None
# 3         Rare Holo                                    None
# 4      Rare Holo GX                                    None
# ...             ...                                     ...
# 18501         Promo                                    None
# 18502         Promo  [{'type': 'Fighting', 'value': '-30'}]
# 18503         Promo                                    None
# 18504         Promo                                    None
# 18505         Promo                                    None
#
#                                         retreatCost  \
# 0                 [Colorless, Colorless, Colorless]
# 1                                              None
# 2                                       [Colorless]
# 3                                       [Colorless]
# 4      [Colorless, Colorless, Colorless, Colorless]
# ...                                             ...
# 18501                        [Colorless, Colorless]
# 18502             [Colorless, Colorless, Colorless]
# 18503                        [Colorless, Colorless]
# 18504                                          None
# 18505                        [Colorless, Colorless]
#
#                                                    rules  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      [TAG TEAM rule: When your TAG TEAM is Knocked ...
# ...                                                  ...
# 18501  [Pokémon ex rule: When your Pokémon ex is Knoc...
# 18502  [Pokémon ex rule: When your Pokémon ex is Knoc...
# 18503  [As long as this Pokémon is on your Bench, pre...
# 18504  [As long as this Pokémon is on your Bench, pre...
# 18505  [As long as this Pokémon is on your Bench, pre...
#
#                                                      set  \
# 0      {'id': 'dp3', 'images': {'symbol': 'https://im...
# 1      {'id': 'ex12', 'images': {'symbol': 'https://i...
# 2      {'id': 'mcd19', 'images': {'symbol': 'https://...
# 3      {'id': 'ex7', 'images': {'symbol': 'https://im...
# 4      {'id': 'sm9', 'images': {'symbol': 'https://im...
# ...                                                  ...
# 18501  {'id': 'svp', 'images': {'symbol': 'https://im...
# 18502  {'id': 'svp', 'images': {'symbol': 'https://im...
# 18503  {'id': 'svp', 'images': {'symbol': 'https://im...
# 18504  {'id': 'svp', 'images': {'symbol': 'https://im...
# 18505  {'id': 'svp', 'images': {'symbol': 'https://im...
#
#                     subtypes supertype  \
# 0                  [Stage 2]   Pokémon
# 1                  [Stage 1]   Pokémon
# 2                    [Basic]   Pokémon
# 3                  [Stage 1]   Pokémon
# 4      [Basic, TAG TEAM, GX]   Pokémon
# ...                      ...       ...
# 18501          [Stage 2, ex]   Pokémon
# 18502          [Stage 1, ex]   Pokémon
# 18503      [Basic, Tera, ex]   Pokémon
# 18504    [Stage 2, Tera, ex]   Pokémon
# 18505      [Basic, Tera, ex]   Pokémon
#
#                                                tcgplayer        types  \
# 0      {'url': 'https://prices.pokemontcg.io/tcgplaye...  [Lightning]
# 1      {'url': 'https://prices.pokemontcg.io/tcgplaye...  [Colorless]
# 2      {'url': 'https://prices.pokemontcg.io/tcgplaye...      [Grass]
# 3      {'url': 'https://prices.pokemontcg.io/tcgplaye...      [Water]
# 4      {'url': 'https://prices.pokemontcg.io/tcgplaye...      [Grass]
# ...                                                  ...          ...
# 18501  {'url': 'https://prices.pokemontcg.io/tcgplaye...       [Fire]
# 18502  {'url': 'https://prices.pokemontcg.io/tcgplaye...    [Psychic]
# 18503                                               None      [Water]
# 18504                                               None       [Fire]
# 18505                                               None  [Colorless]
#
#                                    weaknesses
# 0      [{'type': 'Fighting', 'value': '+30'}]
# 1      [{'type': 'Lightning', 'value': '×2'}]
# 2           [{'type': 'Fire', 'value': '×2'}]
# 3      [{'type': 'Lightning', 'value': '×2'}]
# 4           [{'type': 'Fire', 'value': '×2'}]
# ...                                       ...
# 18501      [{'type': 'Water', 'value': '×2'}]
# 18502   [{'type': 'Darkness', 'value': '×2'}]
# 18503      [{'type': 'Metal', 'value': '×2'}]
# 18504      [{'type': 'Water', 'value': '×2'}]
# 18505   [{'type': 'Fighting', 'value': '×2'}]
#
# [18506 rows x 26 columns]
